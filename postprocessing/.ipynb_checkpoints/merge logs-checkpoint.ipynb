# %%
# %pylab inline
import pandas as pd
# %cd "/Users/yoavfreund/Google Drive File Stream/My Drive/Microphone Arrays/CSV/"
# !ls -lrt | tail
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Volumes/GoogleDrive/My Drive/Microphone Arrays/CSV
# total 440
# -r--------  0 yoavfreund  staff      0 Dec 31  1969 Icon
# -rw-------@ 1 yoavfreund  staff  24630 Sep 13 14:06 ODAS0.csv
# -rw-------  1 yoavfreund  staff  31833 Sep 13 14:06 ODAS2.csv
# -rw-------  1 yoavfreund  staff  30910 Sep 13 14:06 ODAS1.csv
# -rw-------  1 yoavfreund  staff  33846 Sep 13 20:21 ODAS3.csv

# %%
from datetime import datetime
Cols=['sensor','File', 'Start Time', 'End Time', 'Timestamp Length(ms)',
       'Total Timestamps', '0 source detected', '1 source detected',
       '2 source detected', '3 source detected', '4 source detected']
all_df=[]
for i in range(3):
    df=pd.read_csv('ODAS%d.csv'%i)
    df['sensor']=i
    df=df[Cols]
    df['timestamp']=[datetime.fromisoformat(t).timestamp() for t in list(df['Start Time'])]
    df=df.set_index('timestamp')
    df=df.sort_index()
    all_df.append(df)
all_df[2].head(3)
# Out:
#               sensor                          File  \
# timestamp
# 1.568066e+09       2  cSST_2019-09-09_14:50:11.log
# 1.568067e+09       2  cSST_2019-09-09_15:10:04.log
# 1.568067e+09       2  cSST_2019-09-09_15:15:04.log
#
#                               Start Time                    End Time  \
# timestamp
# 1.568066e+09  2019-09-09 14:50:11.480119  2019-09-09 14:54:57.630740
# 1.568067e+09  2019-09-09 15:10:04.273825  2019-09-09 15:14:49.993445
# 1.568067e+09  2019-09-09 15:15:04.313383  2019-09-09 15:19:50.072515
#
#               Timestamp Length(ms)  Total Timestamps  0 source detected  \
# timestamp
# 1.568066e+09                7.9997             35770              34493
# 1.568067e+09                7.9980             35724              21707
# 1.568067e+09                7.9991             35724              13716
#
#               1 source detected  2 source detected  3 source detected  \
# timestamp
# 1.568066e+09               1277                  0                  0
# 1.568067e+09              13148                869                  0
# 1.568067e+09              13804               6692               1389
#
#               4 source detected
# timestamp
# 1.568066e+09                  0
# 1.568067e+09                  0
# 1.568067e+09                123

# %%
cdf=pd.concat(all_df)
cdf=cdf.sort_index()
cdf.head(5)
# Out:
#               sensor                          File  \
# timestamp
# 1.568066e+09       0  cSST_2019-09-09_14:45:11.log
# 1.568066e+09       1  cSST_2019-09-09_14:45:12.log
# 1.568066e+09       0  cSST_2019-09-09_14:50:03.log
# 1.568066e+09       2  cSST_2019-09-09_14:50:11.log
# 1.568066e+09       1  cSST_2019-09-09_14:55:03.log
#
#                               Start Time                    End Time  \
# timestamp
# 1.568066e+09  2019-09-09 14:45:11.427053  2019-09-09 14:49:57.625110
# 1.568066e+09  2019-09-09 14:45:12.438027  2019-09-09 14:49:58.735869
# 1.568066e+09  2019-09-09 14:50:03.745063  2019-09-09 14:54:50.063201
# 1.568066e+09  2019-09-09 14:50:11.480119  2019-09-09 14:54:57.630740
# 1.568066e+09  2019-09-09 14:55:03.883986  2019-09-09 14:59:50.172443
#
#               Timestamp Length(ms)  Total Timestamps  0 source detected  \
# timestamp
# 1.568066e+09                7.9988             35780               8625
# 1.568066e+09                7.9978             35797              29083
# 1.568066e+09                7.9973             35802              33544
# 1.568066e+09                7.9997             35770              34493
# 1.568066e+09                7.9978             35796              35203
#
#               1 source detected  2 source detected  3 source detected  \
# timestamp
# 1.568066e+09              25197               1727                112
# 1.568066e+09               6624                 90                  0
# 1.568066e+09               2258                  0                  0
# 1.568066e+09               1277                  0                  0
# 1.568066e+09                593                  0                  0
#
#               4 source detected
# timestamp
# 1.568066e+09                119
# 1.568066e+09                  0
# 1.568066e+09                  0
# 1.568066e+09                  0
# 1.568066e+09                  0

# %%
cdf.to_csv('combined.csv')

# %%
# !ls
# Out:
# Icon?        ODAS0.csv    ODAS1.csv    ODAS2.csv    ODAS3.csv    combined.csv
