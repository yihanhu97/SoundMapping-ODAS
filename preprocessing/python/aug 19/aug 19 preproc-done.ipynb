# %%
import glob
import os
import pandas as pd
import re 
import json
import datetime
import time
import shutil
import datetime

# Extract time information of each recording from the log file
def timeExtract(filename):
    with open(filename, 'rb') as f:
        # Start counting from the last byte
        counter = 1
        # Go to the 2nd byte before the end of the last line
        f.seek(-2, 2) 
        while f.read(1) != b'\n':
            f.seek(-2, 1)
            counter=counter+1
        endTime_line = f.readline().decode()
        # Go to the 2nd byte before the end of the last second line
        f.seek(-counter-2, 2)
        while f.read(1) != b'\n':
            f.seek(-2, 1)
        startTime_line = f.readline().decode()

    return [startTime_line, endTime_line]

# Calculate duration of each recording in microseconds
def durationinMicroseconds(filename):
    startTime = timeExtract(filename)[0].split()[2:]
    endTime = timeExtract(filename)[1].split()[2:]
    startTimeStr = startTime[0] + ' ' + startTime[1]
    endTimeStr = endTime[0] + ' ' + endTime[1]
    T1 = datetime.datetime.strptime(startTimeStr, '%Y-%m-%d %H:%M:%S.%f')
    T2 = datetime.datetime.strptime(endTimeStr, '%Y-%m-%d %H:%M:%S.%f')
    delta = T2-T1
    duration = delta.seconds*1000000 + delta.microseconds
    
    return duration, T1, T2

# Converts .log files into pandas dataframes
def extractDirectionalities(filename, mic_number):
    with open(filename, 'r') as f:
        text = f.read()

        # Use repex to store blocks of data into a list
    data = re.split('(?<=})\n(?={)', text) 
        # Delete the time info from the last data block
    tmp = data[-1][:(data[-1].rfind("}")+1)]
    data[-1] = tmp
        
    #list of src blocks 

    srcList = [json.loads(block)["src"] for block in data]

    
    #initialize dataframe to have colums: timestamp, time, data inside source
    #timestamp is the initial time stamp
    #time is the datetime value converted from the timestamp and intitial time
    #source is a 4 by 6 array where the rows are the source, and the columns are the source values
    df = pd.DataFrame(columns = ['Timestamp', 'Time', 'Time In Seconds', 'Microphone Number', 'Source ID', 'X', 'Y', 'Z', 'Activity'])
    
    #Used for calculating timestamps -> time
    duration, startTime, endTime = durationinMicroseconds(filename)
    start_time_in_seconds = time.mktime(startTime.timetuple())
    t = duration/len(data) / 1000000.0
    
    index = 1.0
    ind = 0
    df_dict = {}
    for block in srcList:
        if block[0]["id"] != 0 or block[1]["id"] != 0 or block[2]["id"] != 0 or block[3]["id"] != 0:
            time_in_seconds = start_time_in_seconds + (index - 1.0) * t
            for i in range(0, 4):
                if block[i]['id'] != 0:
                    df_dict[ind] = {"Timestamp": [index], "Time":datetime.datetime.fromtimestamp(time_in_seconds).strftime("%A, %B %d, %Y %I:%M:%S"), "Time In Seconds": time_in_seconds, "Microphone Number":mic_number, "Source ID": block[i]["id"], "X": block[i]["x"], "Y": block[i]["y"], "Z": block[i]["z"], "Activity": block[i]["activity"]}
                    ind = ind + 1
                    #df = df.append(pd.DataFrame({"Timestamp": [index], "Time":datetime.datetime.fromtimestamp(time_in_seconds).strftime("%A, %B %d, %Y %I:%M:%S"), "Time In Seconds": time_in_seconds, "Microphone Number":mic_number, "Source ID": block[i]["id"], "X": block[i]["x"], "Y": block[i]["y"], "Z": block[i]["z"], "Activity": block[i]["activity"]}, index=[0]))
        index = index + 1.0
    
    df = df.append(pd.DataFrame.from_dict(df_dict,"index"))
    return(df)

#Main

print("Execution of processAllLogs_new.py started at " + str(datetime.datetime.now()))

records0 = glob.glob('/home/ardelalegre/google-drive/ODAS/logs0/SST/cSST_2020-08-19*.log')
records1 = glob.glob('/home/ardelalegre/google-drive/ODAS/logs1/SST/cSST_2020-08-19*.log')
records2 = glob.glob('/home/ardelalegre/google-drive/ODAS/logs2/SST/cSST_2020-08-19*.log')
records3 = glob.glob('/home/ardelalegre/google-drive/ODAS/logs3/SST/cSST_2020-08-19*.log')
records4 = glob.glob('/home/ardelalegre/google-drive/ODAS/logs4/SST/cSST_2020-08-19*.log')
records5 = glob.glob('/home/ardelalegre/google-drive/ODAS/logs5/SST/cSST_2020-08-19*.log')

records = [records0, records1, records2, records3, records4, records5]

for mic_number in range(len(records)):
    
    destination = "/home/ardelalegre/google-drive/ODAS/logs" + str(mic_number) + "/SST/Processed"
    print("Now processing logs" + str(mic_number))
    
    for log in records[mic_number]:
        try:
            with open(log, 'r') as f:
                    firstline = f.readline()
                    if firstline == "SST log contains no useful data\n":
                        try:
                            temp = shutil.move(log,destination) # new
                        except:
                            continue
                        continue

            log_string = log[:-6] + '.log' # modification to account for added array number to path
    #         print(log_string)

            hour = log_string[log_string.rfind('_') + 1: log_string.rfind('_') + 1 + 2]
            day = log_string[log_string.find('_') + 1: log_string.rfind('_')]
            path = log_string[:log_string.find('S/') + 2] + 'dataframes/dataframes' + str(mic_number) + '/'
    #         print(path)
    #         print(day)
    #         print(hour)
            try:
                if(not os.path.isdir(os.path.join(path, day))):
                    os.mkdir(os.path.join(path, day))

                path = os.path.join(path, day, hour)
                if(not os.path.isdir(path)):
                    print("making directory: " + str(path))
                    os.mkdir(path)

            except:
                continue

    #         print(path)
            try:
                df = extractDirectionalities(log, mic_number)
                if(not os.path.isdir(path)):
                    os.mkdir(path)
                df.to_csv(path_or_buf=path+ '/' + log[log.find('_') + 1:log.find('.')]+'.csv', index=False)
                try:
                    temp = shutil.move(log,destination) # new
                    print('Processed a log and moved it!')
                except:
                    continue
            except:
                print('Could not process file: ' + log)
        except:
            print('Could not open file: ' + log)
            continue
        
        
print("Execution of processAllLogs_new.py ended at " + str(datetime.datetime.now()))
print("\n")
# Out:
# Execution of processAllLogs_new.py started at 2020-08-21 01:52:12.557057
# Now processing logs0
# /home/ardelalegre/.local/lib/python3.5/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %% [markdown]
# ### Combining Dataframes

# %%
# This script combines dataframes from all microphone arrays produced one day ago relative to the date when the script is run

print("\n")
print("Execution of combineDataframes.py started at " + str(datetime.datetime.now()))#define the dates and hours to be combined

today = datetime.datetime.now() # extract todays date
a = today  - datetime.timedelta(days = 2) # extract yesterday's date

a = str(a) # convert into string
year = a[:4] # extract yesterday's year
month = a[5:7] # extract yesterday's month
day = a[8:10] # extract yesterday


hours = []
for i in range(10):
    hours.append('0' + str(i))
for i in range(10, 25):
    hours.append(str(i))

# create date

date = year + '-' + month + '-' + day
date_path = os.path.join('/home/ardelalegre/google-drive/ODAS/dataframes/combined/', date)
for hour in hours:
    dfs = []
    for mic_number in range(6):
        if(not os.path.isdir('/home/ardelalegre/google-drive/ODAS/dataframes/dataframes' + str(mic_number) + '/' + date + '/' + hour + '/')):
            continue

        for file in glob.glob('/home/ardelalegre/google-drive/ODAS/dataframes/dataframes' + str(mic_number) + '/' + date +'/' + hour + '/*.csv'):
            print("Reading file " + file) 
            df = pd.read_csv(file)
            dfs.append(df)
    if(len(dfs) > 0):
        merged = pd.concat(dfs)
        #sort by time
        merged = merged.sort_values(['Time In Seconds'])

        if(not os.path.isdir(date_path)):
            os.mkdir(date_path)
        merged.to_csv(path_or_buf=date_path + '/' + hour + '.csv', index=False)

print("Execution of combineDataframes.py ended at " + str(datetime.datetime.now()))
print("\n")
# Out:
# Execution of combineDataframes.py started at 2020-08-19 15:01:23.804729
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/07/2020-08-19_07:00:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/07/2020-08-19_07:00:03_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes4/2020-08-19/07/2020-08-19_07:00:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes5/2020-08-19/07/2020-08-19_07:00:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/10/2020-08-19_10:50:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/10/2020-08-19_10:45:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/10/2020-08-19_10:50:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/10/2020-08-19_10:40:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/10/2020-08-19_10:45:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/10/2020-08-19_10:55:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/10/2020-08-19_10:55:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/10/2020-08-19_10:50:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/10/2020-08-19_10:40:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/10/2020-08-19_10:30:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/10/2020-08-19_10:45:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/10/2020-08-19_10:55:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/10/2020-08-19_10:40:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/10/2020-08-19_10:50:03_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/10/2020-08-19_10:45:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/10/2020-08-19_10:55:03_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/10/2020-08-19_10:45:29_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/10/2020-08-19_10:55:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/10/2020-08-19_10:40:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/10/2020-08-19_10:45:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/10/2020-08-19_10:50:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes4/2020-08-19/10/2020-08-19_10:50:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:15:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:35:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:05:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:50:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:50:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:55:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:25:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:20:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:45:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:30:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:45:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:40:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:10:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:40:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:10:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:05:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:35:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:00:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:15:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:00:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:55:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:20:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/11/2020-08-19_11:30:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:30:03_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:30:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:35:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:25:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:10:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:05:03_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:55:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:50:03_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:45:03_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:25:03_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:10:03_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:05:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:55:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:20:03_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:50:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:15:03_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:00:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:35:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:15:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:40:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:40:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:00:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:45:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/11/2020-08-19_11:20:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/11/2020-08-19_11:45:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/11/2020-08-19_11:20:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/11/2020-08-19_11:00:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/11/2020-08-19_11:35:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/11/2020-08-19_11:55:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/11/2020-08-19_11:25:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/11/2020-08-19_11:10:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/11/2020-08-19_11:30:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/11/2020-08-19_11:50:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/11/2020-08-19_11:40:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/11/2020-08-19_11:15:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/11/2020-08-19_11:05:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/11/2020-08-19_11:15:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/11/2020-08-19_11:00:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/11/2020-08-19_11:50:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/11/2020-08-19_11:10:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/11/2020-08-19_11:40:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/11/2020-08-19_11:35:03_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/11/2020-08-19_11:55:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/11/2020-08-19_11:20:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/11/2020-08-19_11:05:03_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/11/2020-08-19_11:25:13_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/11/2020-08-19_11:45:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes4/2020-08-19/11/2020-08-19_11:25:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes4/2020-08-19/11/2020-08-19_11:55:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes4/2020-08-19/11/2020-08-19_11:40:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes4/2020-08-19/11/2020-08-19_11:15:03_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:05:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:55:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:00:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:55:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:10:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:50:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:35:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:10:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:30:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:45:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:40:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:00:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:05:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:30:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:40:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/12/2020-08-19_12:45:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:25:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:05:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:45:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:00:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:55:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:45:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:55:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:10:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:00:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:30:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:30:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:10:03_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/12/2020-08-19_12:05:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/12/2020-08-19_12:05:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/12/2020-08-19_12:00:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/12/2020-08-19_12:10:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/12/2020-08-19_12:20:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/12/2020-08-19_12:55:04_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/12/2020-08-19_12:40:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/12/2020-08-19_12:30:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/12/2020-08-19_12:05:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/12/2020-08-19_12:50:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/12/2020-08-19_12:00:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes4/2020-08-19/12/2020-08-19_12:35:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes4/2020-08-19/12/2020-08-19_12:05:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:25:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:40:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:50:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:35:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:30:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:25:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:10:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:15:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:20:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:55:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:10:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:05:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:15:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:30:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:00:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:00:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:05:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:20:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/13/2020-08-19_13:45:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:05:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:10:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:55:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:25:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:45:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:40:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:30:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:20:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:25:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:00:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:00:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:35:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:15:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:50:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/13/2020-08-19_13:20:04_1.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/13/2020-08-19_13:30:04_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/13/2020-08-19_13:00:04_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/13/2020-08-19_13:25:04_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/13/2020-08-19_13:05:04_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes2/2020-08-19/13/2020-08-19_13:20:03_2.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes3/2020-08-19/13/2020-08-19_13:00:04_3.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes4/2020-08-19/13/2020-08-19_13:15:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/14/2020-08-19_14:00:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/14/2020-08-19_14:20:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/14/2020-08-19_14:15:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/14/2020-08-19_14:10:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-08-19/14/2020-08-19_14:05:04_4.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/14/2020-08-19_14:15:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/14/2020-08-19_14:00:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/14/2020-08-19_14:20:04_5.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes1/2020-08-19/14/2020-08-19_14:05:04_5.csv
# Execution of combineDataframes.py ended at 2020-08-19 15:28:34.352264

# %% [markdown]
# ### Converting the csv files into a matrix
