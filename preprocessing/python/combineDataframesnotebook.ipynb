# %%
# This script combines dataframes from all microphone arrays produced one day ago relative to the date when the script is run

import glob
import os
import pandas as pd
import re
import json
import datetime
import time

#define the dates and hours to be combined

today = datetime.datetime.now() # extract todays date
a = today - datetime.timedelta(days = 1) # extract yesterday's date

a = str(a) # convert into string
year = a[:4] # extract yesterday's year
month = a[5:7] # extract yesterday's month
day = a[8:10] # extract yesterday


hours = []
for i in range(10):
    hours.append('0' + str(i))
for i in range(10, 25):
    hours.append(str(i))

#iterate through dates and combine. Then for each hour, for each array if a directory exists for that hour, list all the csv files for that hour. Read them and append 

date = year + '-' + month + '-' + day
date_path = os.path.join('/home/ardelalegre/google-drive/ODAS/dataframes/combined/', date)
for hour in hours:
    dfs = []
    for mic_number in range(4):
        if(not os.path.isdir('/home/ardelalegre/google-drive/ODAS/dataframes/dataframes' + str(mic_number) + '/' + date + '/' + hour + '/')):
            continue

        for file in glob.glob('/home/ardelalegre/google-drive/ODAS/dataframes/dataframes' + str(mic_number) + '/' + date +'/' + hour + '/*.csv'):
            print("Reading file " + file) 
            df = pd.read_csv(file)
            dfs.append(df)
    if(len(dfs) > 0):
        merged = pd.concat(dfs)
        #sort by time
        merged = merged.sort_values(['Time In Seconds'])

        if(not os.path.isdir(date_path)):
            os.mkdir(date_path)
        merged.to_csv(path_or_buf=date_path + '/' + hour + '.csv', index=False)
# Out:
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/07/2020-07-09_07:30:03_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/10/2020-07-09_10:40:03_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/10/2020-07-09_10:50:03_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/11/2020-07-09_11:05:03_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/11/2020-07-09_11:25:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/11/2020-07-09_11:30:03_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/11/2020-07-09_11:50:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/11/2020-07-09_11:55:03_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/12/2020-07-09_12:05:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/12/2020-07-09_12:10:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/12/2020-07-09_12:15:03_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/12/2020-07-09_12:25:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/12/2020-07-09_12:30:03_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/12/2020-07-09_12:35:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/12/2020-07-09_12:45:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/12/2020-07-09_12:50:03_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/12/2020-07-09_12:55:03_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/13/2020-07-09_13:00:03_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/13/2020-07-09_13:05:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/13/2020-07-09_13:10:03_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/13/2020-07-09_13:15:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/13/2020-07-09_13:30:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/13/2020-07-09_13:45:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/13/2020-07-09_13:50:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/13/2020-07-09_13:55:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/14/2020-07-09_14:00:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/14/2020-07-09_14:05:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/14/2020-07-09_14:10:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/14/2020-07-09_14:15:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/14/2020-07-09_14:25:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/14/2020-07-09_14:30:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/14/2020-07-09_14:35:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/14/2020-07-09_14:40:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/14/2020-07-09_14:50:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/14/2020-07-09_14:55:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/15/2020-07-09_15:00:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/15/2020-07-09_15:05:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/15/2020-07-09_15:10:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/15/2020-07-09_15:15:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/15/2020-07-09_15:20:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/15/2020-07-09_15:25:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/15/2020-07-09_15:30:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/15/2020-07-09_15:35:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/15/2020-07-09_15:40:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/15/2020-07-09_15:45:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/15/2020-07-09_15:50:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/15/2020-07-09_15:55:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/16/2020-07-09_16:00:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/16/2020-07-09_16:05:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/16/2020-07-09_16:15:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/16/2020-07-09_16:20:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/16/2020-07-09_16:25:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/16/2020-07-09_16:30:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/16/2020-07-09_16:35:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/16/2020-07-09_16:40:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/16/2020-07-09_16:45:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/16/2020-07-09_16:50:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/16/2020-07-09_16:55:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/17/2020-07-09_17:00:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/17/2020-07-09_17:05:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/17/2020-07-09_17:10:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/17/2020-07-09_17:15:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/17/2020-07-09_17:20:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/17/2020-07-09_17:25:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/17/2020-07-09_17:30:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/17/2020-07-09_17:35:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/17/2020-07-09_17:45:04_0.csv
# Reading file /home/ardelalegre/google-drive/ODAS/dataframes/dataframes0/2020-07-09/17/2020-07-09_17:55:04_0.csv
